# %% [markdown]
# # Test Correctnes of RCSB PDB Dimer Download

# %%
import pandas as pd
import os
import matplotlib as plt

# %%
base_dir = "/nfs/scratch/pdb_dimers"
selected_assemblies = pd.read_csv(os.path.join(base_dir, "final_filtered_interactions.tsv"), sep="\t")

selected_assemblies.head()
# Out:
#   assembly_id pdb_id  assembly_number    entity_pair           uniprot_pair  \
# 0      10BL-1   10BL                1  10BL_1,10BL_1          Q4E2L0|Q4E2L0
# 1      10FT-1   10FT                1  10FT_1,10FT_2          Q99435|Q78DX7
# 2      10JU-1   10JU                1  10JU_1,10JU_2          Q582V7|Q582V7
# 3      10LI-1   10LI                1  10LI_1,10LI_1  A0A0D6FAR3|A0A0D6FAR3
# 4      10NM-1   10NM                1  10NM_1,10NM_1          K4FZF8|K4FZF8
#
#     uniprot_1   uniprot_2                                       species_pair  \
# 0      Q4E2L0      Q4E2L0                Trypanosoma cruzi|Trypanosoma cruzi
# 1      Q99435      Q78DX7                          Homo sapiens|Mus musculus
# 2      Q582V7      Q582V7  Trypanosoma brucei brucei TREU927|Trypanosoma ...
# 3  A0A0D6FAR3  A0A0D6FAR3  Salmonella enterica subsp. enterica serovar Ty...
# 4      K4FZF8      K4FZF8                            Glycine max|Glycine max
#
#                                            species_1  \
# 0                                  Trypanosoma cruzi
# 1                                       Homo sapiens
# 2                  Trypanosoma brucei brucei TREU927
# 3  Salmonella enterica subsp. enterica serovar Ty...
# 4                                        Glycine max
#
#                                            species_2  ... taxonomy_2  \
# 0                                  Trypanosoma cruzi  ...       5693
# 1                                       Mus musculus  ...      10090
# 2                  Trypanosoma brucei brucei TREU927  ...     185431
# 3  Salmonella enterica subsp. enterica serovar Ty...  ...      90371
# 4                                        Glycine max  ...       3847
#
#   dimer_type  cluster_pair_100pct             new_cluster_pair  \
# 0       homo  20385_100,20385_100  fix_18845_100,fix_18845_100
# 1     hetero  10609_100,17054_100  fix_14530_100,fix_37352_100
# 2     hetero  65494_100,65494_100  fix_18848_100,fix_18846_100
# 3       homo  50102_100,50102_100  fix_31296_100,fix_31296_100
# 4       homo  41941_100,41941_100  fix_20451_100,fix_20451_100
#
#   resolution_best_angstrom modeled_polymer_monomer_count  experimental_method  \
# 0                     2.60                           664                X-ray
# 1                     3.21                           775                   EM
# 2                     2.15                           522                X-ray
# 3                     1.67                           924                X-ray
# 4                     2.92                           897                   EM
#
#    oligomeric_count                                       download_url  \
# 0                 2  https://files.rcsb.org/download/10bl-assembly1...
# 1                 2  https://files.rcsb.org/download/10ft-assembly1...
# 2                 2  https://files.rcsb.org/download/10ju-assembly1...
# 3                 2  https://files.rcsb.org/download/10li-assembly1...
# 4                 2  https://files.rcsb.org/download/10nm-assembly1...
#
#           local_filename
# 0  10bl-assembly1.cif.gz
# 1  10ft-assembly1.cif.gz
# 2  10ju-assembly1.cif.gz
# 3  10li-assembly1.cif.gz
# 4  10nm-assembly1.cif.gz
#
# [5 rows x 22 columns]

# %% [markdown]
# ### PDB IDs appear multiple times ?

# %%
selected_assemblies['pdb_id'].value_counts()
# Out:
# pdb_id
# 5OCH    4
# 6BZF    4
# 7ZVE    4
# 7ZVY    4
# 3C8G    3
#        ..
# 9ZMZ    1
# 9ZNN    1
# 9ZNO    1
# 9ZVM    1
# 9ZZV    1
# Name: count, Length: 21984, dtype: int64

# %%
# 5OCH
selected_assemblies[selected_assemblies['pdb_id'] == "5OCH"]
# Out:
#       assembly_id pdb_id  assembly_number    entity_pair   uniprot_pair  \
# 13859      5OCH-1   5OCH                1  5OCH_1,5OCH_2  Q9NUT2|Q9NUT2
# 13860      5OCH-2   5OCH                2  5OCH_1,5OCH_1  Q9NUT2|Q9NUT2
# 13861      5OCH-3   5OCH                3  5OCH_3,5OCH_4  Q9NUT2|Q9NUT2
# 13862      5OCH-4   5OCH                4  5OCH_4,5OCH_5  Q9NUT2|Q9NUT2
#
#       uniprot_1 uniprot_2               species_pair     species_1  \
# 13859    Q9NUT2    Q9NUT2  Homo sapiens|Homo sapiens  Homo sapiens
# 13860    Q9NUT2    Q9NUT2  Homo sapiens|Homo sapiens  Homo sapiens
# 13861    Q9NUT2    Q9NUT2  Homo sapiens|Homo sapiens  Homo sapiens
# 13862    Q9NUT2    Q9NUT2  Homo sapiens|Homo sapiens  Homo sapiens
#
#           species_2  ... taxonomy_2 dimer_type  cluster_pair_100pct  \
# 13859  Homo sapiens  ...       9606     hetero  21453_100,21453_100
# 13860  Homo sapiens  ...       9606       homo  21453_100,21453_100
# 13861  Homo sapiens  ...       9606     hetero  21453_100,21453_100
# 13862  Homo sapiens  ...       9606     hetero  21453_100,21453_100
#
#                   new_cluster_pair resolution_best_angstrom  \
# 13859  fix_16443_100,fix_16445_100                      3.4
# 13860  fix_16443_100,fix_16443_100                      3.4
# 13861  fix_16446_100,fix_16444_100                      3.4
# 13862  fix_16444_100,fix_16442_100                      3.4
#
#       modeled_polymer_monomer_count  experimental_method  oligomeric_count  \
# 13859                          1125                X-ray                 2
# 13860                          1110                X-ray                 2
# 13861                          1149                X-ray                 2
# 13862                          1100                X-ray                 2
#
#                                             download_url  \
# 13859  https://files.rcsb.org/download/5och-assembly1...
# 13860  https://files.rcsb.org/download/5och-assembly2...
# 13861  https://files.rcsb.org/download/5och-assembly3...
# 13862  https://files.rcsb.org/download/5och-assembly4...
#
#               local_filename
# 13859  5och-assembly1.cif.gz
# 13860  5och-assembly2.cif.gz
# 13861  5och-assembly3.cif.gz
# 13862  5och-assembly4.cif.gz
#
# [4 rows x 22 columns]

# %%
# 3C8G
selected_assemblies[selected_assemblies['pdb_id'] == "3C8G"]
# Out:
#      assembly_id pdb_id  assembly_number    entity_pair   uniprot_pair  \
# 6108      3C8G-1   3C8G                1  3C8G_1,3C8G_1  Q83Q96|Q83Q96
# 6109      3C8G-2   3C8G                2  3C8G_1,3C8G_2  Q83Q96|Q83Q96
# 6110      3C8G-3   3C8G                3  3C8G_3,3C8G_3  Q83Q96|Q83Q96
#
#      uniprot_1 uniprot_2                                       species_pair  \
# 6108    Q83Q96    Q83Q96  Shigella flexneri 2a str. 2457T|Shigella flexn...
# 6109    Q83Q96    Q83Q96  Shigella flexneri 2a str. 2457T|Shigella flexn...
# 6110    Q83Q96    Q83Q96  Shigella flexneri 2a str. 2457T|Shigella flexn...
#
#                             species_1                        species_2  ...  \
# 6108  Shigella flexneri 2a str. 2457T  Shigella flexneri 2a str. 2457T  ...
# 6109  Shigella flexneri 2a str. 2457T  Shigella flexneri 2a str. 2457T  ...
# 6110  Shigella flexneri 2a str. 2457T  Shigella flexneri 2a str. 2457T  ...
#
#      taxonomy_2 dimer_type  cluster_pair_100pct             new_cluster_pair  \
# 6108     198215       homo  31190_100,31190_100  fix_38614_100,fix_38614_100
# 6109     198215     hetero  31190_100,31190_100  fix_38614_100,fix_38612_100
# 6110     198215       homo  31190_100,31190_100  fix_38613_100,fix_38613_100
#
#      resolution_best_angstrom modeled_polymer_monomer_count  \
# 6108                      2.5                           332
# 6109                      2.5                           333
# 6110                      2.5                           322
#
#       experimental_method  oligomeric_count  \
# 6108                X-ray                 2
# 6109                X-ray                 2
# 6110                X-ray                 2
#
#                                            download_url         local_filename
# 6108  https://files.rcsb.org/download/3c8g-assembly1...  3c8g-assembly1.cif.gz
# 6109  https://files.rcsb.org/download/3c8g-assembly2...  3c8g-assembly2.cif.gz
# 6110  https://files.rcsb.org/download/3c8g-assembly3...  3c8g-assembly3.cif.gz
#
# [3 rows x 22 columns]

# %% [markdown]
# ### Homo vs Hetero

# %%
dimer_counts = selected_assemblies["dimer_type"].value_counts()

ax = dimer_counts.plot.pie(
    autopct="%1.1f%%",
    figsize=(5, 5),
    ylabel="",
    title="Homo vs Hetero Dimers"
)
ax.set_aspect("equal")
